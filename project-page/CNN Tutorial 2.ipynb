# %%
# example of loading the mnist dataset
from keras.datasets import mnist
from matplotlib import pyplot

# load dataset
(trainX, trainy), (testX, testy) = mnist.load_data()

# summarize loaded dataset
print('Train: X=%s, y=%s' % (trainX.shape, trainy.shape))
print('Test: X=%s, y=%s' % (testX.shape, testy.shape))

#plot first few images
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# plot raw https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npzpixel data
	pyplot.imshow(trainX[i], cmap=pyplot.get_cmap('gray'))

    # show the figure
pyplot.show()
# Out:
# Train: X=(60000, 28, 28), y=(60000,)
# Test: X=(10000, 28, 28), y=(10000,)

# %%
# baseline cnn model for mnist
from numpy import mean
from numpy import std
from matplotlib import pyplot
from sklearn.model_selection import KFold
from keras.datasets import mnist
#from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
#from keras.optimizers import SGD
import tensorflow as tf
 
# load train and test dataset
def load_dataset():
	# load dataset
	(trainX, trainY), (testX, testY) = mnist.load_data()
	# reshape dataset to have a single channel
	trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
	testX = testX.reshape((testX.shape[0], 28, 28, 1))
	# one hot encode target values
	trainY = tf.keras.utils.to_categorical(trainY)
	testY = tf.keras.utils.to_categorical(testY)
	return trainX, trainY, testX, testY
 
# scale pixels
def prep_pixels(train, test):
	# convert from integers to floats
	train_norm = train.astype('float32')
	test_norm = test.astype('float32')
	# normalize to range 0-1
	train_norm = train_norm / 255.0
	test_norm = test_norm / 255.0
	# return normalized images
	return train_norm, test_norm
 
# define cnn model
def define_model():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
	model.add(MaxPooling2D((2, 2)))
	model.add(Flatten())
	model.add(Dense(100, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dense(10, activation='softmax'))
	# compile model
	opt = opt='SGD'#(learning_rate=0.01, momentum=0.9)
	model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
	return model
 
# evaluate a model using k-fold cross-validation
def evaluate_model(dataX, dataY, n_folds=5):
	scores, histories = list(), list()
	# prepare cross validation
	kfold = KFold(n_folds, shuffle=True, random_state=1)
	# enumerate splits
	for train_ix, test_ix in kfold.split(dataX):
		# define model
		model = define_model()
		# select rows for train and test
		trainX, trainY, testX, testY = dataX[train_ix], dataY[train_ix], dataX[test_ix], dataY[test_ix]
		# fit model
		history = model.fit(trainX, trainY, epochs=10, batch_size=32, validation_data=(testX, testY), verbose=2)
		# evaluate model
		_, acc = model.evaluate(testX, testY, verbose=0)
		print('> %.3f' % (acc * 100.0))
		# stores scores
		scores.append(acc)
		histories.append(history)
	return scores, histories
 
# plot diagnostic learning curves
def summarize_diagnostics(histories):
	for i in range(len(histories)):
		# plot loss
		pyplot.subplot(2, 1, 1)
		pyplot.title('Cross Entropy Loss')
		pyplot.plot(histories[i].history['loss'], color='blue', label='train')
		pyplot.plot(histories[i].history['val_loss'], color='orange', label='test')
		# plot accuracy
		pyplot.subplot(2, 1, 2)
		pyplot.title('Classification Accuracy')
		pyplot.plot(histories[i].history['accuracy'], color='blue', label='train')
		pyplot.plot(histories[i].history['val_accuracy'], color='orange', label='test')
	pyplot.show()
 
# summarize model performance
def summarize_performance(scores):
	# print summary
	print('Accuracy: mean=%.3f std=%.3f, n=%d' % (mean(scores)*100, std(scores)*100, len(scores)))
	# box and whisker plots of results
	pyplot.boxplot(scores)
	pyplot.show()
 
# run the test harness for evaluating a model
def run_test_harness():
	# load dataset
	trainX, trainY, testX, testY = load_dataset()
	# prepare pixel data
	trainX, testX = prep_pixels(trainX, testX)
	# evaluate model
	scores, histories = evaluate_model(trainX, trainY)
	# learning curves
	summarize_diagnostics(histories)
	# summarize estimated performance
	summarize_performance(scores)
 
# entry point, run the test harness
run_test_harness()
# Out:
# Epoch 1/10
# 1500/1500 - 18s - loss: 0.3098 - accuracy: 0.9115 - val_loss: 0.1790 - val_accuracy: 0.9501
# Epoch 2/10
# 1500/1500 - 8s - loss: 0.1569 - accuracy: 0.9550 - val_loss: 0.1345 - val_accuracy: 0.9607
# Epoch 3/10
# 1500/1500 - 8s - loss: 0.1167 - accuracy: 0.9669 - val_loss: 0.1165 - val_accuracy: 0.9643
# Epoch 4/10
# 1500/1500 - 8s - loss: 0.0939 - accuracy: 0.9731 - val_loss: 0.0994 - val_accuracy: 0.9714
# Epoch 5/10
# 1500/1500 - 8s - loss: 0.0791 - accuracy: 0.9775 - val_loss: 0.0841 - val_accuracy: 0.9761
# Epoch 6/10
# 1500/1500 - 8s - loss: 0.0686 - accuracy: 0.9807 - val_loss: 0.0894 - val_accuracy: 0.9740
# Epoch 7/10
# 1500/1500 - 8s - loss: 0.0591 - accuracy: 0.9828 - val_loss: 0.0722 - val_accuracy: 0.9789
# Epoch 8/10
# 1500/1500 - 8s - loss: 0.0537 - accuracy: 0.9846 - val_loss: 0.0750 - val_accuracy: 0.9775
# Epoch 9/10
# 1500/1500 - 9s - loss: 0.0473 - accuracy: 0.9861 - val_loss: 0.0694 - val_accuracy: 0.9791
# Epoch 10/10
# 1500/1500 - 8s - loss: 0.0427 - accuracy: 0.9878 - val_loss: 0.0723 - val_accuracy: 0.9798
# > 97.983
# Epoch 1/10
# 1500/1500 - 10s - loss: 0.3172 - accuracy: 0.9105 - val_loss: 0.2220 - val_accuracy: 0.9360
# Epoch 2/10
# 1500/1500 - 8s - loss: 0.1590 - accuracy: 0.9545 - val_loss: 0.1594 - val_accuracy: 0.9543
# Epoch 3/10
# 1500/1500 - 8s - loss: 0.1184 - accuracy: 0.9661 - val_loss: 0.1249 - val_accuracy: 0.9647
# Epoch 4/10
# 1500/1500 - 8s - loss: 0.0953 - accuracy: 0.9731 - val_loss: 0.1039 - val_accuracy: 0.9702
# Epoch 5/10
# 1500/1500 - 8s - loss: 0.0795 - accuracy: 0.9778 - val_loss: 0.0925 - val_accuracy: 0.9739
# Epoch 6/10
# 1500/1500 - 8s - loss: 0.0683 - accuracy: 0.9809 - val_loss: 0.0847 - val_accuracy: 0.9753
# Epoch 7/10
# 1500/1500 - 8s - loss: 0.0593 - accuracy: 0.9833 - val_loss: 0.0825 - val_accuracy: 0.9758
# Epoch 8/10
# 1500/1500 - 8s - loss: 0.0528 - accuracy: 0.9852 - val_loss: 0.0773 - val_accuracy: 0.9765
# Epoch 9/10
# 1500/1500 - 8s - loss: 0.0475 - accuracy: 0.9866 - val_loss: 0.0733 - val_accuracy: 0.9774
# Epoch 10/10
# 1500/1500 - 8s - loss: 0.0428 - accuracy: 0.9881 - val_loss: 0.0672 - val_accuracy: 0.9807
# > 98.067
# Epoch 1/10
# 1500/1500 - 9s - loss: 0.3165 - accuracy: 0.9090 - val_loss: 0.2158 - val_accuracy: 0.9365
# Epoch 2/10
# 1500/1500 - 8s - loss: 0.1688 - accuracy: 0.9509 - val_loss: 0.1466 - val_accuracy: 0.9567
# Epoch 3/10
# 1500/1500 - 8s - loss: 0.1262 - accuracy: 0.9633 - val_loss: 0.1326 - val_accuracy: 0.9599
# Epoch 4/10
# 1500/1500 - 8s - loss: 0.1021 - accuracy: 0.9710 - val_loss: 0.1074 - val_accuracy: 0.9679
# Epoch 5/10
# 1500/1500 - 8s - loss: 0.0852 - accuracy: 0.9764 - val_loss: 0.0968 - val_accuracy: 0.9688
# Epoch 6/10
# 1500/1500 - 8s - loss: 0.0742 - accuracy: 0.9790 - val_loss: 0.0870 - val_accuracy: 0.9718
# Epoch 7/10
# 1500/1500 - 8s - loss: 0.0644 - accuracy: 0.9825 - val_loss: 0.0820 - val_accuracy: 0.9751
# Epoch 8/10
# 1500/1500 - 8s - loss: 0.0564 - accuracy: 0.9846 - val_loss: 0.0851 - val_accuracy: 0.9715
# Epoch 9/10
# 1500/1500 - 8s - loss: 0.0513 - accuracy: 0.9859 - val_loss: 0.0795 - val_accuracy: 0.9743
# Epoch 10/10
# 1500/1500 - 8s - loss: 0.0464 - accuracy: 0.9876 - val_loss: 0.0718 - val_accuracy: 0.9775
# > 97.750
# Epoch 1/10
# 1500/1500 - 9s - loss: 0.3191 - accuracy: 0.9117 - val_loss: 0.2074 - val_accuracy: 0.9330
# Epoch 2/10
# 1500/1500 - 8s - loss: 0.1606 - accuracy: 0.9536 - val_loss: 0.1358 - val_accuracy: 0.9603
# Epoch 3/10
# 1500/1500 - 8s - loss: 0.1192 - accuracy: 0.9660 - val_loss: 0.1025 - val_accuracy: 0.9709
# Epoch 4/10
# 1500/1500 - 8s - loss: 0.0956 - accuracy: 0.9733 - val_loss: 0.0903 - val_accuracy: 0.9753
# Epoch 5/10
# 1500/1500 - 8s - loss: 0.0805 - accuracy: 0.9771 - val_loss: 0.0832 - val_accuracy: 0.9758
# Epoch 6/10
# 1500/1500 - 8s - loss: 0.0701 - accuracy: 0.9807 - val_loss: 0.0739 - val_accuracy: 0.9797
# Epoch 7/10
# 1500/1500 - 8s - loss: 0.0615 - accuracy: 0.9832 - val_loss: 0.0699 - val_accuracy: 0.9797
# Epoch 8/10
# 1500/1500 - 8s - loss: 0.0554 - accuracy: 0.9849 - val_loss: 0.0640 - val_accuracy: 0.9803
# Epoch 9/10
# 1500/1500 - 8s - loss: 0.0496 - accuracy: 0.9863 - val_loss: 0.0602 - val_accuracy: 0.9815
# Epoch 10/10
# 1500/1500 - 8s - loss: 0.0455 - accuracy: 0.9876 - val_loss: 0.0585 - val_accuracy: 0.9824
# > 98.242
# Epoch 1/10
# 1500/1500 - 9s - loss: 0.3223 - accuracy: 0.9072 - val_loss: 0.2019 - val_accuracy: 0.9433
# Epoch 2/10
# 1500/1500 - 8s - loss: 0.1622 - accuracy: 0.9530 - val_loss: 0.1349 - val_accuracy: 0.9620
# Epoch 3/10
# 1500/1500 - 8s - loss: 0.1190 - accuracy: 0.9659 - val_loss: 0.1149 - val_accuracy: 0.9670
# Epoch 4/10
# 1500/1500 - 8s - loss: 0.0942 - accuracy: 0.9734 - val_loss: 0.0963 - val_accuracy: 0.9739
# Epoch 5/10
# 1500/1500 - 8s - loss: 0.0781 - accuracy: 0.9774 - val_loss: 0.0839 - val_accuracy: 0.9767
# Epoch 6/10
# 1500/1500 - 8s - loss: 0.0667 - accuracy: 0.9810 - val_loss: 0.0817 - val_accuracy: 0.9781
# Epoch 7/10
# 1500/1500 - 8s - loss: 0.0580 - accuracy: 0.9835 - val_loss: 0.0804 - val_accuracy: 0.9772
# Epoch 8/10
# 1500/1500 - 8s - loss: 0.0515 - accuracy: 0.9858 - val_loss: 0.0683 - val_accuracy: 0.9816
# Epoch 9/10
# 1500/1500 - 8s - loss: 0.0458 - accuracy: 0.9874 - val_loss: 0.0645 - val_accuracy: 0.9818
# Epoch 10/10
# 1500/1500 - 8s - loss: 0.0419 - accuracy: 0.9883 - val_loss: 0.0615 - val_accuracy: 0.9833
# > 98.325
# Accuracy: mean=98.073 std=0.202, n=5
